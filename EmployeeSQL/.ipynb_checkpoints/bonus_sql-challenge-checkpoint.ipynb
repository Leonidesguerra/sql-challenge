# %%
# Dependencies and Setup
import pandas as pd
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
from config import pw

# %%
#connection to postgress 
engine = create_engine(f'postgresql://postgres:{pw}@localhost:5432/PH_employee')
conn = engine.connect()

#import sql databases
salaries = pd.read_sql('SELECT * FROM salaries', conn)
title_sal = pd.read_sql("SELECT t.title, s.salary\
                        FROM titles AS t\
                        INNER JOIN employees AS e ON t.title_id = e.emp_title_id\
                        INNER JOIN salaries AS s ON e.emp_no = s.emp_no", conn)

employee=pd.read_sql('SELECT * FROM employees', conn)

# %%
#plot histogram of salary ranges
x = salaries['salary']
plt.hist(x, bins = 20)
plt.xticks(rotation='vertical')
plt.title('HP Employee Salaries')
plt.xlabel('Salary Range')
plt.ylabel('# of emoployees')
plt.show()

# by analysing this histogram, misleading data can be observed where there are 120,000+ employees whith a $40,000 salary
# this could mean that data was falsely introduced to the database.

# %%
salary_per_title=title_sal.groupby('title').mean()
salary_per_title.reset_index(inplace=True)

# %%
plt.figure(figsize=(10,6))
pyplot_bar=plt.bar(salary_per_title['title'],salary_per_title['salary'], width= 0.5)
plt.xticks(rotation='vertical')
plt.title('Average Salary per Job Title at Pewlett Hackard')
plt.xlabel('job title')
plt.ylabel('salary')
plt.show()

#the false data seems to be evenly distributed among all job titles

# %%
#by researching the employee number 499942 the name April Foolsday  comes up, confirming the suspicion of false data

employee.loc[employee['emp_no']== 499942]
# Out:
#         emp_no emp_title_id  birth_date first_name last_name sex   hire_date
# 168736  499942        e0004  1963-01-10      April  Foolsday   F  1997-02-10
